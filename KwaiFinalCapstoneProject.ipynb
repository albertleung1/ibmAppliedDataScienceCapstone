# %%
##################################################################################################################
#                                                                                                                #
# Project Title: Find a place to open a restaurant                                                               #
#                                                                                                                #
# Description:                                                                                                   #
# A customer is looking for a place to open restaurant in Baltimore County, Maryland, USA. In order              #
# to select the place with high population but less restaurants (at least not much fast food), use data from     #
# Foursquare to do analysis and recommend couple location for customer.                                          #
#                                                                                                                #
# Method:                                                                                                        #
# Use the geographic information from Internet (source: unitedstateszipcodes.org) and merge with the venue       #
# information from Foursquare to find out the potential places to open fast food/American style restaurant in    # 
# Baltimore County, Maryland, USA.                                                                               #
#                                                                                                                #
##################################################################################################################

# %%
from traitlets.config import Config
import nbformat as nbf
from nbconvert.exporters import HTMLExporter

c = Config()

c.TagRemovePreprocessor.remove_cell_tags = ("remove_cell",)

# %%
# Import the libraries we need in the project
# Import requests #Library to handle requests

import pandas as pd #Library for data analysis
import numpy as np #Library to handle data in a vectorized manner
import json
import random #Library for random number generation

import requests
from pandas.io.json import json_normalize

import matplotlib.cm as cm
import matplotlib.colors as colors

from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0
import folium as folium

# Libraries for displaying images
from IPython.display import Image
from IPython.core.display import HTML

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
# Use pandas read_cvs to read the postal data
postalData = pd.read_csv('zip_code_database.csv')
postalData.head()
# Out:
#    zip      type  decommissioned primary_city acceptable_cities  \
# 0  501    UNIQUE               0   Holtsville               NaN
# 1  544    UNIQUE               0   Holtsville               NaN
# 2  601  STANDARD               0     Adjuntas               NaN
# 3  602  STANDARD               0       Aguada               NaN
# 4  603  STANDARD               0    Aguadilla             Ramey
#
#                                  unacceptable_cities state  \
# 0                               I R S Service Center    NY
# 1                                 Irs Service Center    NY
# 2  Colinas Del Gigante, Jard De Adjuntas, Urb San...    PR
# 3  Alts De Aguada, Bo Guaniquilla, Comunidad Las ...    PR
# 4  Bda Caban, Bda Esteves, Bo Borinquen, Bo Ceiba...    PR
#
#                 county             timezone area_codes world_region country  \
# 0       Suffolk County     America/New_York        631          NaN      US
# 1       Suffolk County     America/New_York        631          NaN      US
# 2   Adjuntas Municipio  America/Puerto_Rico    787,939          NaN      US
# 3     Aguada Municipio  America/Puerto_Rico    787,939          NaN      US
# 4  Aguadilla Municipio  America/Puerto_Rico        787          NaN      US
#
#    latitude  longitude  irs_estimated_population_2015
# 0     40.81     -73.04                            562
# 1     40.81     -73.04                              0
# 2     18.16     -66.72                              0
# 3     18.38     -67.18                              0
# 4     18.43     -67.15                              0

# %%
# Now, clean up the data and keep only the column and data we need. The target area is Baltimore County, Maryland, USA.
MDData = postalData.drop(columns=['decommissioned', 'unacceptable_cities', 'timezone', 'world_region'])
MDData.sort_values(by='irs_estimated_population_2015', ascending=False)
# Out:
#          zip      type primary_city acceptable_cities state            county  \
# 26692  60629  STANDARD      Chicago      Bedford Park    IL       Cook County
# 4118   11220  STANDARD     Brooklyn               NaN    NY      Kings County
# 34023  77449  STANDARD         Katy          Park Row    TX     Harris County
# 3135    8701  STANDARD     Lakewood               NaN    NJ      Ocean County
# 34065  77494  STANDARD         Katy          Park Row    TX  Fort Bend County
# ...      ...       ...          ...               ...   ...               ...
# 10029  24042    UNIQUE      Roanoke               NaN    VA      Roanoke City
# 10030  24043    UNIQUE      Roanoke               NaN    VA      Roanoke City
# 10031  24044    UNIQUE      Roanoke               NaN    VA      Roanoke City
# 10032  24045    UNIQUE      Roanoke               NaN    VA      Roanoke City
# 10660  25389  STANDARD   Charleston               NaN    WV    Kanawha County
#
#         area_codes country  latitude  longitude  irs_estimated_population_2015
# 26692  312,773,872      US     41.78     -87.71                         114420
# 4118           718      US     40.64     -74.02                         111430
# 34023  281,346,832      US     29.84     -95.73                         109280
# 3135   732,848,908      US     40.09     -74.21                         105330
# 34065      281,832      US     29.74     -95.83                         104450
# ...            ...     ...       ...        ...                            ...
# 10029          540      US     37.27     -79.95                              0
# 10030          540      US     37.27     -79.95                              0
# 10031          540      US     37.27     -79.94                              0
# 10032          540      US     37.27     -79.94                              0
# 10660      304,681      US     38.35     -81.63                              0
#
# [42632 rows x 11 columns]

# %%
# Clean up the data and filter to Baltimore County, Maryland, USA. And the population is above 20,000

MDData = MDData[(MDData['type'] == 'UNIQUE') | (MDData['type'] == 'STANDARD')]  
MDData = MDData[(MDData['state'] == 'MD') & (MDData['county'] == 'Baltimore County') & (MDData['irs_estimated_population_2015'] > 20000)]
MDData.sort_values(by='irs_estimated_population_2015', ascending=False, inplace=True)
MDData.groupby(['primary_city'])
MDData
# Out:
#         zip      type          primary_city  \
# 8929  21234  STANDARD             Parkville
# 8871  21117  STANDARD          Owings Mills
# 8918  21222  STANDARD               Dundalk
# 8924  21228  STANDARD           Catonsville
# 8903  21207  STANDARD             Gwynn Oak
# 8917  21221  STANDARD                 Essex
# 8916  21220  STANDARD          Middle River
# 8931  21236  STANDARD            Nottingham
# 8860  21093  STANDARD  Lutherville Timonium
# 8936  21244  STANDARD          Windsor Mill
# 8880  21136  STANDARD          Reisterstown
# 8923  21227  STANDARD            Halethorpe
# 8904  21208  STANDARD            Pikesville
# 8932  21237  STANDARD              Rosedale
# 8879  21133  STANDARD          Randallstown
# 8905  21209  STANDARD             Baltimore
# 8820  21030  STANDARD          Cockeysville
#
#                          acceptable_cities state            county  \
# 8929                             Baltimore    MD  Baltimore County
# 8871                              Garrison    MD  Baltimore County
# 8918                             Baltimore    MD  Baltimore County
# 8924                             Baltimore    MD  Baltimore County
# 8903                   Baltimore, Woodlawn    MD  Baltimore County
# 8917                             Baltimore    MD  Baltimore County
# 8916                             Baltimore    MD  Baltimore County
# 8931                             Baltimore    MD  Baltimore County
# 8860  Lutherville, Luthvle Timon, Timonium    MD  Baltimore County
# 8936                             Baltimore    MD  Baltimore County
# 8880                               Glyndon    MD  Baltimore County
# 8923         Arbutus, Baltimore, Lansdowne    MD  Baltimore County
# 8904                             Baltimore    MD  Baltimore County
# 8932                             Baltimore    MD  Baltimore County
# 8879                          Mcdonogh Run    MD  Baltimore County
# 8905       Mount Washington, Mt Washington    MD  Baltimore County
# 8820                Cockysvil, Hunt Valley    MD  Baltimore County
#
#        area_codes country  latitude  longitude  irs_estimated_population_2015
# 8929      410,443      US     39.38     -76.55                          62620
# 8871          410      US     39.41     -76.79                          52350
# 8918      410,443      US     39.26     -76.49                          50150
# 8924      410,443      US     39.26     -76.74                          44840
# 8903  667,410,443      US     39.32     -76.72                          42570
# 8917      410,443      US     39.30     -76.44                          38480
# 8916      410,443      US     39.33     -76.43                          38290
# 8931          410      US     39.39     -76.48                          37560
# 8860          410      US     39.43     -76.64                          36780
# 8936          410      US     39.33     -76.78                          34200
# 8880      410,443      US     39.45     -76.81                          33560
# 8923  240,443,410      US     39.24     -76.68                          31860
# 8904  410,443,667      US     39.39     -76.70                          31470
# 8932          410      US     39.32     -76.50                          28580
# 8879      410,443      US     39.37     -76.80                          28230
# 8905          410      US     39.37     -76.67                          25520
# 8820      410,443      US     39.47     -76.63                          24550

# %%
MDData.shape
# Out:
# (17, 11)

# %%
tags:["remove_cell"]
#Test this
